# %%
import mod
# 모듈을 가져오는법 import - 외부 파일을 로드
# 사용 : 모듈이름.클래스()
# from mod import 클래스 ---> 사용 : 클래스명()

# %%
# 모듈 안에 변수를 호출
mod.test_vari
# Out:
# '모듈 안에 있는 텍스트'

# %%
mod.func_1(1,2)
# Out:
# 3

# %%
user1 = mod.User('kim', 30)

# %%
user1.work('A')
# Out:
# 입금완료 : 잔액 10000입니다
